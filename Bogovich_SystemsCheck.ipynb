# %% [markdown]
# # This is a header!

# %% [markdown]
# ## This is a subheader!

# %% [markdown]
# **This is Bold**

# %% [markdown]
# *This is Italic*

# %% [markdown]
# 1. Ordered List item 1.
# 2. Ordered List item 2.
# 3. Ordered List item 3.

# %% [markdown]
# ![My Image](jason.jpg)

# %% [raw]
# I hope to learn more about technology and refresh my understanding of technology in this class.

# %%
x = 5

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
    print("hello world")
# Out:
# hello world

# %%
def addNumbers(a, b):
    result = a+b
    return result
addNumbers(3, 4)
# Out:
# 7
